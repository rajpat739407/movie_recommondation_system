# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import pickle
import importlib

# Force reload the recommendation engine
import src.recommendation_engine as engine_module
importlib.reload(engine_module)
from src.recommendation_engine import MovieRecommendationEngine

print("🎬 MOVIE RECOMMENDATION SYSTEM - FINAL DEMO")
print("=" * 60)

# Load data
print("📂 Loading data...")
movies_processed = pd.read_csv('../data/movies_processed.csv')

with open('../data/user_encoder.pkl', 'rb') as f:
    user_encoder = pickle.load(f)

with open('../data/movie_encoder.pkl', 'rb') as f:
    movie_encoder = pickle.load(f)

print(f"✅ Data loaded: {len(movies_processed)} movies")

# Initialize engine
engine = MovieRecommendationEngine(movies_processed, user_encoder, movie_encoder)

# Load models with debugging
print("\n🔄 Loading trained models...")
success = engine.load_trained_models()

if success:
    print("\n🎉 SYSTEM READY! Testing recommendations...")
    print("=" * 50)
    
    # Get some actual user IDs
    ratings = pd.read_csv('../data/ratings_processed.csv')
    sample_users = ratings['userId'].value_counts().head(3).index.tolist()
    
    for user_id in sample_users:
        print(f"\n📋 Recommendations for User {user_id}:")
        print("-" * 40)
        
        recommendations = engine.get_user_recommendations(
            user_id, 
            method='hybrid', 
            n_recommendations=3
        )
        
        if isinstance(recommendations, list) and recommendations:
            for i, rec in enumerate(recommendations):
                print(f"   {i+1}. {rec['title']}")
                print(f"      🎭 {rec['genres']}")
                print(f"      ⭐ Score: {rec['score']:.3f}")
        else:
            print(f"   ❌ {recommendations}")
    
    # Test movie similarity
    print(f"\n🔍 Testing movie similarity:")
    print("-" * 40)
    
    # Get a movie that exists
    test_movie = movies_processed.iloc[10]  # Use a different index if needed
    print(f"🎬 Finding movies similar to: {test_movie['title']}")
    
    similar = engine.get_movie_similarity(test_movie['movieId'], n_similar=2)
    
    if isinstance(similar, list) and similar:
        for i, movie in enumerate(similar):
            print(f"   {i+1}. {movie['title']}")
            print(f"      🎭 {movie['genres']}")
            print(f"      🔗 Similarity: {movie['similarity_score']:.3f}")
    else:
        print(f"   ❌ {similar}")

else:
    print("\n❌ Failed to load models. Check the error messages above.")

print("\n" + "=" * 60)
print("🎉 DEMO COMPLETED!")
print("=" * 60)
# Out:
# 🎬 MOVIE RECOMMENDATION SYSTEM - FINAL DEMO
# ============================================================
# 📂 Loading data...
# ✅ Data loaded: 86537 movies
#
# 🔄 Loading trained models...
# Loading trained models...
# 🔍 Checking model files...
#    ✅ ../models/knn_model.pkl - EXISTS
#    ✅ ../models/svd_model.pkl - EXISTS
#    ✅ ../models/factorized_matrix.npy - EXISTS
#    ✅ ../data/user_item_matrix_sparse.npz - EXISTS
# 📊 Loading user-item matrix...
#    User-item matrix loaded: (307411, 32004)
# 🤖 Loading KNN model...
#    KNN model loaded successfully
# 🔧 Loading SVD model...
#    SVD model loaded successfully
# 📈 Loading factorized matrix...
#    Factorized matrix loaded: (307411, 100)
# 🎉 All models loaded successfully!
#
# 🎉 SYSTEM READY! Testing recommendations...
# ==================================================
#
# 📋 Recommendations for User 189614:
# ----------------------------------------
# 👤 User ID 189614 -> Index 176279
# 🔄 Generating hybrid recommendations...
# 🔍 Finding similar users for user index 176279...
#    Found 19 similar users
#    Generated 3 recommendations
# 🔧 Generating SVD recommendations for user index 176279...
#    Generated 3 SVD recommendations
#    Final hybrid recommendations: 3 movies
#    1. Bank Job, The (2008)
#       🎭 Action|Crime|Thriller
#       ⭐ Score: 3.263
#    2. Red (2010)
#       🎭 Action|Comedy
#       ⭐ Score: 2.500
#    3. Courage Under Fire (1996)
#       🎭 Action|Crime|Drama|War
#       ⭐ Score: 2.395
#
# 📋 Recommendations for User 48766:
# ----------------------------------------
# 👤 User ID 48766 -> Index 45404
# 🔄 Generating hybrid recommendations...
# 🔍 Finding similar users for user index 45404...
#    Found 19 similar users
#    Generated 3 recommendations
# 🔧 Generating SVD recommendations for user index 45404...
#    Generated 3 SVD recommendations
#    Final hybrid recommendations: 3 movies
#    1. Trainspotting (1996)
#       🎭 Comedy|Crime|Drama
#       ⭐ Score: 3.842
#    2. The Revenant (2015)
#       🎭 Adventure|Drama
#       ⭐ Score: 3.816
#    3. Star Wars: Episode VII - The Force Awakens (2015)
#       🎭 Action|Adventure|Fantasy|Sci-Fi|IMAX
#       ⭐ Score: 3.684
#
# 📋 Recommendations for User 207216:
# ----------------------------------------
# 👤 User ID 207216 -> Index 192639
# 🔄 Generating hybrid recommendations...
# 🔍 Finding similar users for user index 192639...
#    Found 19 similar users
#    Generated 3 recommendations
# 🔧 Generating SVD recommendations for user index 192639...
#    Generated 3 SVD recommendations
#    Final hybrid recommendations: 3 movies
#    1. Fahrenheit 9/11 (2004)
#       🎭 Documentary
#       ⭐ Score: 2.868
#    2. Solaris (Solyaris) (1972)
#       🎭 Drama|Mystery|Sci-Fi
#       ⭐ Score: 2.868
#    3. Bowling for Columbine (2002)
#       🎭 Documentary
#       ⭐ Score: 2.789
#
# 🔍 Testing movie similarity:
# ----------------------------------------
# 🎬 Finding movies similar to: American President, The (1995)
# 🔍 Finding movies similar to ID 11...
#    Movie ID 11 -> Index 10
#    ❌ Error finding similar movies: index 100 is out of bounds for axis 0 with size 100
#
# ============================================================
# 🎉 DEMO COMPLETED!
# ============================================================
